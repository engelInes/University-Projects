# %%
# !pip3 uninstall -y torch torchvision
# Out:
# Found existing installation: torch 2.2.0
# Uninstalling torch-2.2.0:
#   Successfully uninstalled torch-2.2.0
# Found existing installation: torchvision 0.17.1
# Uninstalling torchvision-0.17.1:
#   Successfully uninstalled torchvision-0.17.1
# WARNING: Skipping C:\Users\Ines\anaconda3\envs\AI\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Ines\anaconda3\envs\AI\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'
# WARNING: Skipping C:\Users\Ines\anaconda3\envs\AI\Lib\site-packages\numpy-1.26.4.dist-info due to invalid metadata entry 'name'

# %%
# !pip3 install torch torchvision
# Out:
# ...
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.2 MB 1.1 MB/s eta 0:00:02
#    --------------- ------------------------ 0.5/1.2 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------ --- 1.1/1.2 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 7.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/198.6 MB ? eta -:--:--
#    ---------------------------------------- 1.6/198.6 MB 34.7 MB/s eta 0:00:06
#    ---------------------------------------- 2.0/198.6 MB 31.7 MB/s eta 0:00:07
#    ---------------------------------------- 2.2/198.6 MB 17.1 MB/s eta 0:00:12
#     --------------------------------------- 3.5/198.6 MB 22.1 MB/s eta 0:00:09
#     --------------------------------------- 3.9/198.6 MB 19.1 MB/s eta 0:00:11
#     --------------------------------------- 4.5/198.6 MB 18.1 MB/s eta 0:00:11
# ...
