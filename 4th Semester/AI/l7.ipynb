# %%
import torch
import torchvision
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# Load an image file into a PyTorch tensor
image = torchvision.io.read_image('corgi.jpg')

# %%
# Create a grid of images
grid = torchvision.utils.make_grid(image)

# Display the grid using matplotlib
plt.imshow(grid.permute(1, 2, 0))
plt.show()

# %%
# Load an image file into a Python array
image = Image.open('corgi.jpg')
image_array = np.array(image)

# Display the image using matplotlib
plt.imshow(image_array)
plt.show()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (8, 8)

# %%
images = torch.rand(10, 1, 28, 28)

# Build 6 conv. filters
conv_filters = nn.Conv2d(in_channels=1, out_channels=6, kernel_size=(3, 3), stride=1, padding=1)

# Convolve the image with the filters
output_feature = conv_filters(images)
print(output_feature.shape)
# Out:
# torch.Size([10, 6, 28, 28])

# %%
# Load an image file into a PyTorch tensor
image = torchvision.io.read_image('corgi.jpg').float()

# Normalize the pixel values to be between 0 and 1
image /= 255.0

# %%
# Define a convolutional filter with 3 input channels, 10 output channels, and a kernel size of 3
conv_filter = nn.Conv2d(3, 10, kernel_size=3)

# %%
print(image.shape)
# Out:
# torch.Size([3, 334, 515])

# %%
output = conv_filter(image)

# %%
# Create a grid of images
grid = torchvision.utils.make_grid(output)
# Display the grid using matplotlib
plt.imshow(output.detach()[2]) # One 0 is the batch and one is the signal (RGB)
plt.show()

#This is just 1 random filter

# %%
# Ex 1: Look at some other channels
# Display the first channel of the output tensor
plt.imshow(output.detach()[0])
plt.show()

# %%
# Display the second channel of the output tensor
plt.imshow(output.detach()[1])
plt.show()

# %%
import torchvision
from torchvision import datasets
from torchvision.transforms import ToTensor

# Setup training data
train_data = datasets.FashionMNIST(
    root="data", # where to download data to?
    train=True, # get training data
    download=True, # download data if it doesn't exist on disk
    transform=ToTensor(), # images come as PIL format, we want to turn into Torch tensors
    target_transform=None # you can transform labels as well
)

# Setup testing data
test_data = datasets.FashionMNIST(
    root="data",
    train=False, # get test data
    download=True,
    transform=ToTensor()
)
# Out:
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to data/FashionMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 26421880/26421880 [00:01<00:00, 18475704.72it/s]
# Extracting data/FashionMNIST/raw/train-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 29515/29515 [00:00<00:00, 343887.09it/s]
# Extracting data/FashionMNIST/raw/train-labels-idx1-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 4422102/4422102 [00:00<00:00, 6220172.53it/s]
# Extracting data/FashionMNIST/raw/t10k-images-idx3-ubyte.gz to data/FashionMNIST/raw
#
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 5148/5148 [00:00<00:00, 15324540.09it/s]
# Extracting data/FashionMNIST/raw/t10k-labels-idx1-ubyte.gz to data/FashionMNIST/raw

# %%
# See first training sample
image, label = train_data[0]
image, label
# Out:
# (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
#            0.2863, 0.0000, 0.0000, 0.0039, 0.0157, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000, 0.1412, 0.5333,
#            0.4980, 0.2431, 0.2118, 0.0000, 0.0000, 0.0000, 0.0039, 0.0118,
#            0.0157, 0.0000, 0.0000, 0.0118],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0235, 0.0000, 0.4000, 0.8000,
#            0.6902, 0.5255, 0.5647, 0.4824, 0.0902, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0471, 0.0392, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6078, 0.9255,
#            0.8118, 0.6980, 0.4196, 0.6118, 0.6314, 0.4275, 0.2510, 0.0902,
#            0.3020, 0.5098, 0.2824, 0.0588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.2706, 0.8118, 0.8745,
#            0.8549, 0.8471, 0.8471, 0.6392, 0.4980, 0.4745, 0.4784, 0.5725,
#            0.5529, 0.3451, 0.6745, 0.2588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0039, 0.0000, 0.7843, 0.9098, 0.9098,
#            0.9137, 0.8980, 0.8745, 0.8745, 0.8431, 0.8353, 0.6431, 0.4980,
#            0.4824, 0.7686, 0.8980, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7176, 0.8824, 0.8471,
#            0.8745, 0.8941, 0.9216, 0.8902, 0.8784, 0.8706, 0.8784, 0.8667,
#            0.8745, 0.9608, 0.6784, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7569, 0.8941, 0.8549,
#            0.8353, 0.7765, 0.7059, 0.8314, 0.8235, 0.8275, 0.8353, 0.8745,
#            0.8627, 0.9529, 0.7922, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0118, 0.0000, 0.0471, 0.8588, 0.8627, 0.8314,
#            0.8549, 0.7529, 0.6627, 0.8902, 0.8157, 0.8549, 0.8784, 0.8314,
#            0.8863, 0.7725, 0.8196, 0.2039],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0235, 0.0000, 0.3882, 0.9569, 0.8706, 0.8627,
#            0.8549, 0.7961, 0.7765, 0.8667, 0.8431, 0.8353, 0.8706, 0.8627,
#            0.9608, 0.4667, 0.6549, 0.2196],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0157, 0.0000, 0.0000, 0.2157, 0.9255, 0.8941, 0.9020,
#            0.8941, 0.9412, 0.9098, 0.8353, 0.8549, 0.8745, 0.9176, 0.8510,
#            0.8510, 0.8196, 0.3608, 0.0000],
#           [0.0000, 0.0000, 0.0039, 0.0157, 0.0235, 0.0275, 0.0078, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.9294, 0.8863, 0.8510, 0.8745,
#            0.8706, 0.8588, 0.8706, 0.8667, 0.8471, 0.8745, 0.8980, 0.8431,
#            0.8549, 1.0000, 0.3020, 0.0000],
#           [0.0000, 0.0118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.2431, 0.5686, 0.8000, 0.8941, 0.8118, 0.8353, 0.8667,
#            0.8549, 0.8157, 0.8275, 0.8549, 0.8784, 0.8745, 0.8588, 0.8431,
#            0.8784, 0.9569, 0.6235, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.1725, 0.3216, 0.4196,
#            0.7412, 0.8941, 0.8627, 0.8706, 0.8510, 0.8863, 0.7843, 0.8039,
#            0.8275, 0.9020, 0.8784, 0.9176, 0.6902, 0.7373, 0.9804, 0.9725,
#            0.9137, 0.9333, 0.8431, 0.0000],
#           [0.0000, 0.2235, 0.7333, 0.8157, 0.8784, 0.8667, 0.8784, 0.8157,
#            0.8000, 0.8392, 0.8157, 0.8196, 0.7843, 0.6235, 0.9608, 0.7569,
#            0.8078, 0.8745, 1.0000, 1.0000, 0.8667, 0.9176, 0.8667, 0.8275,
#            0.8627, 0.9098, 0.9647, 0.0000],
#           [0.0118, 0.7922, 0.8941, 0.8784, 0.8667, 0.8275, 0.8275, 0.8392,
#            0.8039, 0.8039, 0.8039, 0.8627, 0.9412, 0.3137, 0.5882, 1.0000,
#            0.8980, 0.8667, 0.7373, 0.6039, 0.7490, 0.8235, 0.8000, 0.8196,
#            0.8706, 0.8941, 0.8824, 0.0000],
#           [0.3843, 0.9137, 0.7765, 0.8235, 0.8706, 0.8980, 0.8980, 0.9176,
#            0.9765, 0.8627, 0.7608, 0.8431, 0.8510, 0.9451, 0.2549, 0.2863,
#            0.4157, 0.4588, 0.6588, 0.8588, 0.8667, 0.8431, 0.8510, 0.8745,
#            0.8745, 0.8784, 0.8980, 0.1137],
#           [0.2941, 0.8000, 0.8314, 0.8000, 0.7569, 0.8039, 0.8275, 0.8824,
#            0.8471, 0.7255, 0.7725, 0.8078, 0.7765, 0.8353, 0.9412, 0.7647,
#            0.8902, 0.9608, 0.9373, 0.8745, 0.8549, 0.8314, 0.8196, 0.8706,
#            0.8627, 0.8667, 0.9020, 0.2627],
#           [0.1882, 0.7961, 0.7176, 0.7608, 0.8353, 0.7725, 0.7255, 0.7451,
#            0.7608, 0.7529, 0.7922, 0.8392, 0.8588, 0.8667, 0.8627, 0.9255,
#            0.8824, 0.8471, 0.7804, 0.8078, 0.7294, 0.7098, 0.6941, 0.6745,
#            0.7098, 0.8039, 0.8078, 0.4510],
#           [0.0000, 0.4784, 0.8588, 0.7569, 0.7020, 0.6706, 0.7176, 0.7686,
#            0.8000, 0.8235, 0.8353, 0.8118, 0.8275, 0.8235, 0.7843, 0.7686,
#            0.7608, 0.7490, 0.7647, 0.7490, 0.7765, 0.7529, 0.6902, 0.6118,
#            0.6549, 0.6941, 0.8235, 0.3608],
#           [0.0000, 0.0000, 0.2902, 0.7412, 0.8314, 0.7490, 0.6863, 0.6745,
#            0.6863, 0.7098, 0.7255, 0.7373, 0.7412, 0.7373, 0.7569, 0.7765,
#            0.8000, 0.8196, 0.8235, 0.8235, 0.8275, 0.7373, 0.7373, 0.7608,
#            0.7529, 0.8471, 0.6667, 0.0000],
#           [0.0078, 0.0000, 0.0000, 0.0000, 0.2588, 0.7843, 0.8706, 0.9294,
#            0.9373, 0.9490, 0.9647, 0.9529, 0.9569, 0.8667, 0.8627, 0.7569,
#            0.7490, 0.7020, 0.7137, 0.7137, 0.7098, 0.6902, 0.6510, 0.6588,
#            0.3882, 0.2275, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1569,
#            0.2392, 0.1725, 0.2824, 0.1608, 0.1373, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000]]]),
#  9)

# %%
# See classes
class_names = train_data.classes
class_names
# Out:
# ['T-shirt/top',
#  'Trouser',
#  'Pullover',
#  'Dress',
#  'Coat',
#  'Sandal',
#  'Shirt',
#  'Sneaker',
#  'Bag',
#  'Ankle boot']

# %%
#ex 2 Print the length of the train and test datasets.
print(f"Length of train dataset: {len(train_data)}")
print(f"Length of test dataset: {len(test_data)}")
# Out:
# Length of train dataset: 60000
# Length of test dataset: 10000

# %%
import matplotlib.pyplot as plt
image, label = train_data[0]
print(f"Image shape: {image.shape}")
plt.imshow(image.squeeze()) # image shape is [1, 28, 28] (colour channels, height, width)
plt.title(label);
# Out:
# Image shape: torch.Size([1, 28, 28])

# %%
# Ex 3 Access some random data from train_data
# Plot more images
torch.manual_seed(42)
fig = plt.figure(figsize=(9, 9))
rows, cols = 4, 4
for i in range(1, rows * cols + 1):
    random_idx = torch.randint(0, len(train_data), size=[1]).item()
    # Exercise 3 here
    img, label = train_data[random_idx]
    fig.add_subplot(rows, cols, i)
    plt.imshow(img.squeeze(), cmap="gray")
    plt.title(class_names[label])
    plt.axis(False);

# %%
from torch.utils.data import DataLoader

# Setup the batch size hyperparameter
BATCH_SIZE = 32

# Turn datasets into iterables (batches)
train_dataloader = DataLoader(train_data, # dataset to turn into iterable
    batch_size=BATCH_SIZE, # how many samples per batch?
    shuffle=True # shuffle data every epoch?
)

test_dataloader = DataLoader(test_data,
    batch_size=BATCH_SIZE,
    shuffle=False # don't necessarily have to shuffle the testing data
)

# Let's check out what we've created
print(f"Dataloaders: {train_dataloader, test_dataloader}")
print(f"Length of train dataloader: {len(train_dataloader)} batches of {BATCH_SIZE}")
print(f"Length of test dataloader: {len(test_dataloader)} batches of {BATCH_SIZE}")
# Out:
# Dataloaders: (<torch.utils.data.dataloader.DataLoader object at 0x7d8a620edfc0>, <torch.utils.data.dataloader.DataLoader object at 0x7d8a6b5a4940>)
# Length of train dataloader: 1875 batches of 32
# Length of test dataloader: 313 batches of 32

# %%
# Check out what's inside the training dataloader
# This is how we get some random samples
train_features_batch, train_labels_batch = next(iter(train_dataloader))
train_features_batch.shape, train_labels_batch.shape
# Out:
# (torch.Size([32, 1, 28, 28]), torch.Size([32]))

# %%
#ex 4 Use Flatten + 2x Linear layer for the base model.
from torch import nn
class FashionMNISTModelV0(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            # Exercise 4 here
            torch.nn.Flatten(),
            torch.nn.Linear(input_shape, hidden_units),
            torch.nn.Linear(hidden_units, output_shape)
        )

    def forward(self, x):
        return self.layer_stack(x)

# %%
torch.manual_seed(42)

# Need to setup model with input parameters
model_0 = FashionMNISTModelV0(input_shape=784, # one for every pixel (28x28)
    hidden_units=10, # how many units in the hidden layer
    output_shape=len(class_names) # one for every class
)

# %%
def accuracy_fn(y_true, y_pred):
    """
    Calculates accuracy between truth labels and predictions.

    Args:
        y_true (torch.Tensor): Truth labels for predictions.
        y_pred (torch.Tensor): Predictions to be compared to predictions.

    Returns:
        [torch.float]: Accuracy value between y_true and y_pred, e.g. 78.45
    """
    correct = torch.eq(y_true, y_pred).sum().item()
    acc = (correct / len(y_pred)) * 100
    return acc

# %%
#Ex 5 Define the loss as Cross Entropy loss and the sgd optimizer.
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model_0.parameters(), lr=0.1)

# %%
from timeit import default_timer as timer
def print_train_time(start: float, end: float, device: torch.device = None):
    """
    Prints difference between start and end time.

    Args:
        start (float): Start time of computation (preferred in timeit format).
        end (float): End time of computation.
        device ([type], optional): Device that compute is running on. Defaults to None.

    Returns:
        float: time between start and end in seconds (higher is longer).
    """
    total_time = end - start
    print(f"Train time on {device}: {total_time:.3f} seconds")
    return total_time

# %%
#Ex 6 Create a loss_values_arr and plot it after the training loop.
# Initialize the loss values array
num_epochs = 3
loss_values_arr = []
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_dataloader):
        # Move images and labels to device
        # images = images.to(device)
        # labels = labels.to(device)

        # Forward pass
        outputs = model_0(images)
        loss = loss_fn(outputs, labels)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Store the loss value
        loss_values_arr.append(loss.item())

        # Print the loss and accuracy every 100 iterations
        if (i+1) % 3 == 0:
            print(f"Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_dataloader)}], Loss: {loss.item():.4f}")

# Plot the loss values
plt.plot(loss_values_arr)
plt.title("Training Loss")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.show()
# Out:
# Epoch [1/3], Step [3/1875], Loss: 2.2362
# Epoch [1/3], Step [6/1875], Loss: 2.1264
# Epoch [1/3], Step [9/1875], Loss: 2.0594
# Epoch [1/3], Step [12/1875], Loss: 1.9412
# Epoch [1/3], Step [15/1875], Loss: 1.6340
# Epoch [1/3], Step [18/1875], Loss: 1.7663
# Epoch [1/3], Step [21/1875], Loss: 1.6881
# Epoch [1/3], Step [24/1875], Loss: 1.4429
# Epoch [1/3], Step [27/1875], Loss: 1.4127
# Epoch [1/3], Step [30/1875], Loss: 1.1795
# Epoch [1/3], Step [33/1875], Loss: 1.2385
# Epoch [1/3], Step [36/1875], Loss: 1.1886
# Epoch [1/3], Step [39/1875], Loss: 1.2850
# Epoch [1/3], Step [42/1875], Loss: 0.9569
# Epoch [1/3], Step [45/1875], Loss: 1.0638
# Epoch [1/3], Step [48/1875], Loss: 1.0610
# Epoch [1/3], Step [51/1875], Loss: 0.8532
# Epoch [1/3], Step [54/1875], Loss: 0.8418
# Epoch [1/3], Step [57/1875], Loss: 0.7616
# Epoch [1/3], Step [60/1875], Loss: 0.9404
# Epoch [1/3], Step [63/1875], Loss: 0.8473
# Epoch [1/3], Step [66/1875], Loss: 0.9786
# Epoch [1/3], Step [69/1875], Loss: 0.9943
# Epoch [1/3], Step [72/1875], Loss: 0.8570
# Epoch [1/3], Step [75/1875], Loss: 0.7525
# Epoch [1/3], Step [78/1875], Loss: 0.9414
# Epoch [1/3], Step [81/1875], Loss: 0.8181
# Epoch [1/3], Step [84/1875], Loss: 0.7532
# Epoch [1/3], Step [87/1875], Loss: 0.9290
# Epoch [1/3], Step [90/1875], Loss: 0.7938
# Epoch [1/3], Step [93/1875], Loss: 0.5578
# Epoch [1/3], Step [96/1875], Loss: 1.0596
# Epoch [1/3], Step [99/1875], Loss: 0.9319
# Epoch [1/3], Step [102/1875], Loss: 0.7665
# Epoch [1/3], Step [105/1875], Loss: 0.7016
# Epoch [1/3], Step [108/1875], Loss: 0.7668
# Epoch [1/3], Step [111/1875], Loss: 0.6934
# Epoch [1/3], Step [114/1875], Loss: 0.8397
# Epoch [1/3], Step [117/1875], Loss: 0.6550
# Epoch [1/3], Step [120/1875], Loss: 1.0134
# Epoch [1/3], Step [123/1875], Loss: 0.8963
# Epoch [1/3], Step [126/1875], Loss: 0.7336
# Epoch [1/3], Step [129/1875], Loss: 0.9206
# Epoch [1/3], Step [132/1875], Loss: 0.8868
# Epoch [1/3], Step [135/1875], Loss: 0.6457
# Epoch [1/3], Step [138/1875], Loss: 0.9902
# Epoch [1/3], Step [141/1875], Loss: 0.5742
# Epoch [1/3], Step [144/1875], Loss: 0.7237
# Epoch [1/3], Step [147/1875], Loss: 0.7674
# Epoch [1/3], Step [150/1875], Loss: 0.9666
# Epoch [1/3], Step [153/1875], Loss: 0.5939
# Epoch [1/3], Step [156/1875], Loss: 0.5391
# Epoch [1/3], Step [159/1875], Loss: 0.8914
# Epoch [1/3], Step [162/1875], Loss: 0.4997
# Epoch [1/3], Step [165/1875], Loss: 0.5092
# Epoch [1/3], Step [168/1875], Loss: 0.6454
# Epoch [1/3], Step [171/1875], Loss: 0.6002
# Epoch [1/3], Step [174/1875], Loss: 0.8253
# Epoch [1/3], Step [177/1875], Loss: 0.9040
# Epoch [1/3], Step [180/1875], Loss: 0.7044
# Epoch [1/3], Step [183/1875], Loss: 0.6648
# Epoch [1/3], Step [186/1875], Loss: 0.6971
# Epoch [1/3], Step [189/1875], Loss: 0.7755
# Epoch [1/3], Step [192/1875], Loss: 0.6229
# Epoch [1/3], Step [195/1875], Loss: 0.5578
# Epoch [1/3], Step [198/1875], Loss: 0.2719
# Epoch [1/3], Step [201/1875], Loss: 0.5748
# Epoch [1/3], Step [204/1875], Loss: 0.2949
# Epoch [1/3], Step [207/1875], Loss: 0.6442
# Epoch [1/3], Step [210/1875], Loss: 0.4997
# Epoch [1/3], Step [213/1875], Loss: 0.7080
# Epoch [1/3], Step [216/1875], Loss: 0.7959
# Epoch [1/3], Step [219/1875], Loss: 0.6203
# Epoch [1/3], Step [222/1875], Loss: 0.3902
# Epoch [1/3], Step [225/1875], Loss: 0.4982
# Epoch [1/3], Step [228/1875], Loss: 0.7661
# Epoch [1/3], Step [231/1875], Loss: 0.5589
# Epoch [1/3], Step [234/1875], Loss: 0.4508
# Epoch [1/3], Step [237/1875], Loss: 0.7002
# Epoch [1/3], Step [240/1875], Loss: 0.7730
# Epoch [1/3], Step [243/1875], Loss: 0.6470
# Epoch [1/3], Step [246/1875], Loss: 0.6008
# Epoch [1/3], Step [249/1875], Loss: 0.6142
# Epoch [1/3], Step [252/1875], Loss: 0.6793
# Epoch [1/3], Step [255/1875], Loss: 0.9773
# Epoch [1/3], Step [258/1875], Loss: 0.4795
# Epoch [1/3], Step [261/1875], Loss: 0.5711
# Epoch [1/3], Step [264/1875], Loss: 0.5393
# Epoch [1/3], Step [267/1875], Loss: 0.5854
# Epoch [1/3], Step [270/1875], Loss: 0.5324
# Epoch [1/3], Step [273/1875], Loss: 0.6730
# Epoch [1/3], Step [276/1875], Loss: 0.6652
# Epoch [1/3], Step [279/1875], Loss: 0.8206
# Epoch [1/3], Step [282/1875], Loss: 0.8059
# Epoch [1/3], Step [285/1875], Loss: 0.6550
# Epoch [1/3], Step [288/1875], Loss: 0.5388
# Epoch [1/3], Step [291/1875], Loss: 0.4257
# Epoch [1/3], Step [294/1875], Loss: 0.7847
# Epoch [1/3], Step [297/1875], Loss: 0.6289
# Epoch [1/3], Step [300/1875], Loss: 0.3459
# Epoch [1/3], Step [303/1875], Loss: 0.9453
# Epoch [1/3], Step [306/1875], Loss: 0.4850
# Epoch [1/3], Step [309/1875], Loss: 0.6719
# Epoch [1/3], Step [312/1875], Loss: 0.9963
# Epoch [1/3], Step [315/1875], Loss: 0.4326
# Epoch [1/3], Step [318/1875], Loss: 0.7488
# Epoch [1/3], Step [321/1875], Loss: 0.6530
# Epoch [1/3], Step [324/1875], Loss: 0.3558
# Epoch [1/3], Step [327/1875], Loss: 0.4069
# Epoch [1/3], Step [330/1875], Loss: 0.8373
# Epoch [1/3], Step [333/1875], Loss: 0.8173
# Epoch [1/3], Step [336/1875], Loss: 0.4358
# Epoch [1/3], Step [339/1875], Loss: 0.4666
# Epoch [1/3], Step [342/1875], Loss: 0.7068
# Epoch [1/3], Step [345/1875], Loss: 0.7709
# Epoch [1/3], Step [348/1875], Loss: 0.4693
# Epoch [1/3], Step [351/1875], Loss: 0.3691
# Epoch [1/3], Step [354/1875], Loss: 0.1440
# Epoch [1/3], Step [357/1875], Loss: 0.4497
# Epoch [1/3], Step [360/1875], Loss: 0.4688
# Epoch [1/3], Step [363/1875], Loss: 0.7753
# Epoch [1/3], Step [366/1875], Loss: 0.5345
# Epoch [1/3], Step [369/1875], Loss: 0.6796
# Epoch [1/3], Step [372/1875], Loss: 0.7084
# Epoch [1/3], Step [375/1875], Loss: 0.7072
# Epoch [1/3], Step [378/1875], Loss: 0.4251
# Epoch [1/3], Step [381/1875], Loss: 0.4757
# Epoch [1/3], Step [384/1875], Loss: 0.3820
# Epoch [1/3], Step [387/1875], Loss: 0.8686
# Epoch [1/3], Step [390/1875], Loss: 0.5971
# Epoch [1/3], Step [393/1875], Loss: 0.4230
# Epoch [1/3], Step [396/1875], Loss: 0.3897
# Epoch [1/3], Step [399/1875], Loss: 0.2939
# Epoch [1/3], Step [402/1875], Loss: 0.4517
# Epoch [1/3], Step [405/1875], Loss: 0.4733
# Epoch [1/3], Step [408/1875], Loss: 0.6306
# Epoch [1/3], Step [411/1875], Loss: 0.5557
# Epoch [1/3], Step [414/1875], Loss: 0.6024
# Epoch [1/3], Step [417/1875], Loss: 0.3266
# Epoch [1/3], Step [420/1875], Loss: 0.7587
# Epoch [1/3], Step [423/1875], Loss: 0.8861
# Epoch [1/3], Step [426/1875], Loss: 0.3772
# Epoch [1/3], Step [429/1875], Loss: 0.5425
# Epoch [1/3], Step [432/1875], Loss: 0.4718
# Epoch [1/3], Step [435/1875], Loss: 0.3193
# Epoch [1/3], Step [438/1875], Loss: 0.7428
# Epoch [1/3], Step [441/1875], Loss: 0.5041
# Epoch [1/3], Step [444/1875], Loss: 0.3653
# Epoch [1/3], Step [447/1875], Loss: 0.6198
# Epoch [1/3], Step [450/1875], Loss: 0.9749
# Epoch [1/3], Step [453/1875], Loss: 0.5544
# Epoch [1/3], Step [456/1875], Loss: 0.7705
# Epoch [1/3], Step [459/1875], Loss: 0.7176
# Epoch [1/3], Step [462/1875], Loss: 0.3280
# Epoch [1/3], Step [465/1875], Loss: 0.4285
# Epoch [1/3], Step [468/1875], Loss: 0.4908
# Epoch [1/3], Step [471/1875], Loss: 0.5965
# Epoch [1/3], Step [474/1875], Loss: 0.4780
# Epoch [1/3], Step [477/1875], Loss: 0.5163
# Epoch [1/3], Step [480/1875], Loss: 0.2704
# Epoch [1/3], Step [483/1875], Loss: 0.6282
# Epoch [1/3], Step [486/1875], Loss: 0.5771
# Epoch [1/3], Step [489/1875], Loss: 0.7718
# Epoch [1/3], Step [492/1875], Loss: 0.7937
# Epoch [1/3], Step [495/1875], Loss: 0.4551
# Epoch [1/3], Step [498/1875], Loss: 0.6986
# Epoch [1/3], Step [501/1875], Loss: 0.5379
# Epoch [1/3], Step [504/1875], Loss: 0.7946
# Epoch [1/3], Step [507/1875], Loss: 0.2897
# Epoch [1/3], Step [510/1875], Loss: 0.7431
# Epoch [1/3], Step [513/1875], Loss: 0.6800
# Epoch [1/3], Step [516/1875], Loss: 0.4968
# Epoch [1/3], Step [519/1875], Loss: 0.6300
# Epoch [1/3], Step [522/1875], Loss: 0.8742
# Epoch [1/3], Step [525/1875], Loss: 1.2781
# Epoch [1/3], Step [528/1875], Loss: 0.5786
# Epoch [1/3], Step [531/1875], Loss: 0.2150
# Epoch [1/3], Step [534/1875], Loss: 0.4176
# Epoch [1/3], Step [537/1875], Loss: 0.5363
# Epoch [1/3], Step [540/1875], Loss: 0.4411
# Epoch [1/3], Step [543/1875], Loss: 0.7032
# Epoch [1/3], Step [546/1875], Loss: 0.6889
# Epoch [1/3], Step [549/1875], Loss: 1.5129
# Epoch [1/3], Step [552/1875], Loss: 0.7341
# Epoch [1/3], Step [555/1875], Loss: 0.6552
# Epoch [1/3], Step [558/1875], Loss: 0.6120
# Epoch [1/3], Step [561/1875], Loss: 0.6013
# Epoch [1/3], Step [564/1875], Loss: 0.4785
# Epoch [1/3], Step [567/1875], Loss: 0.7043
# Epoch [1/3], Step [570/1875], Loss: 0.8901
# Epoch [1/3], Step [573/1875], Loss: 0.4351
# Epoch [1/3], Step [576/1875], Loss: 0.6608
# Epoch [1/3], Step [579/1875], Loss: 0.6996
# Epoch [1/3], Step [582/1875], Loss: 0.6703
# Epoch [1/3], Step [585/1875], Loss: 0.4102
# Epoch [1/3], Step [588/1875], Loss: 0.6626
# Epoch [1/3], Step [591/1875], Loss: 0.5819
# Epoch [1/3], Step [594/1875], Loss: 0.3302
# Epoch [1/3], Step [597/1875], Loss: 0.2899
# Epoch [1/3], Step [600/1875], Loss: 1.1655
# Epoch [1/3], Step [603/1875], Loss: 0.7950
# Epoch [1/3], Step [606/1875], Loss: 0.5558
# Epoch [1/3], Step [609/1875], Loss: 0.8513
# Epoch [1/3], Step [612/1875], Loss: 0.7020
# Epoch [1/3], Step [615/1875], Loss: 0.4182
# Epoch [1/3], Step [618/1875], Loss: 0.5738
# Epoch [1/3], Step [621/1875], Loss: 0.5293
# Epoch [1/3], Step [624/1875], Loss: 0.5718
# Epoch [1/3], Step [627/1875], Loss: 0.7139
# Epoch [1/3], Step [630/1875], Loss: 0.4549
# Epoch [1/3], Step [633/1875], Loss: 0.2825
# Epoch [1/3], Step [636/1875], Loss: 0.6989
# Epoch [1/3], Step [639/1875], Loss: 0.5788
# Epoch [1/3], Step [642/1875], Loss: 0.5526
# Epoch [1/3], Step [645/1875], Loss: 0.4650
# Epoch [1/3], Step [648/1875], Loss: 0.4786
# Epoch [1/3], Step [651/1875], Loss: 0.4576
# Epoch [1/3], Step [654/1875], Loss: 0.6794
# Epoch [1/3], Step [657/1875], Loss: 0.5183
# Epoch [1/3], Step [660/1875], Loss: 0.4631
# Epoch [1/3], Step [663/1875], Loss: 0.5426
# Epoch [1/3], Step [666/1875], Loss: 0.4180
# Epoch [1/3], Step [669/1875], Loss: 0.7313
# Epoch [1/3], Step [672/1875], Loss: 0.6714
# Epoch [1/3], Step [675/1875], Loss: 0.2788
# Epoch [1/3], Step [678/1875], Loss: 0.5488
# Epoch [1/3], Step [681/1875], Loss: 0.6283
# Epoch [1/3], Step [684/1875], Loss: 0.5154
# Epoch [1/3], Step [687/1875], Loss: 0.5705
# Epoch [1/3], Step [690/1875], Loss: 0.6480
# Epoch [1/3], Step [693/1875], Loss: 0.4887
# Epoch [1/3], Step [696/1875], Loss: 0.5609
# Epoch [1/3], Step [699/1875], Loss: 0.8210
# Epoch [1/3], Step [702/1875], Loss: 0.7266
# Epoch [1/3], Step [705/1875], Loss: 0.3610
# Epoch [1/3], Step [708/1875], Loss: 0.2921
# Epoch [1/3], Step [711/1875], Loss: 0.8197
# Epoch [1/3], Step [714/1875], Loss: 0.5799
# Epoch [1/3], Step [717/1875], Loss: 0.8422
# Epoch [1/3], Step [720/1875], Loss: 0.3148
# Epoch [1/3], Step [723/1875], Loss: 0.3118
# Epoch [1/3], Step [726/1875], Loss: 0.5759
# Epoch [1/3], Step [729/1875], Loss: 0.9183
# Epoch [1/3], Step [732/1875], Loss: 0.8985
# Epoch [1/3], Step [735/1875], Loss: 0.6090
# Epoch [1/3], Step [738/1875], Loss: 0.6647
# Epoch [1/3], Step [741/1875], Loss: 0.6504
# Epoch [1/3], Step [744/1875], Loss: 0.6614
# Epoch [1/3], Step [747/1875], Loss: 0.6855
# Epoch [1/3], Step [750/1875], Loss: 0.7316
# Epoch [1/3], Step [753/1875], Loss: 0.6418
# Epoch [1/3], Step [756/1875], Loss: 0.4509
# Epoch [1/3], Step [759/1875], Loss: 0.4792
# Epoch [1/3], Step [762/1875], Loss: 0.6708
# Epoch [1/3], Step [765/1875], Loss: 0.5479
# Epoch [1/3], Step [768/1875], Loss: 0.5292
# Epoch [1/3], Step [771/1875], Loss: 0.4901
# Epoch [1/3], Step [774/1875], Loss: 0.3974
# Epoch [1/3], Step [777/1875], Loss: 0.4101
# Epoch [1/3], Step [780/1875], Loss: 0.5765
# Epoch [1/3], Step [783/1875], Loss: 0.6941
# Epoch [1/3], Step [786/1875], Loss: 0.5092
# Epoch [1/3], Step [789/1875], Loss: 0.2701
# Epoch [1/3], Step [792/1875], Loss: 0.6086
# Epoch [1/3], Step [795/1875], Loss: 0.5125
# Epoch [1/3], Step [798/1875], Loss: 0.2843
# Epoch [1/3], Step [801/1875], Loss: 0.5087
# Epoch [1/3], Step [804/1875], Loss: 0.3771
# Epoch [1/3], Step [807/1875], Loss: 0.5256
# Epoch [1/3], Step [810/1875], Loss: 0.3451
# Epoch [1/3], Step [813/1875], Loss: 0.6917
# Epoch [1/3], Step [816/1875], Loss: 0.9084
# Epoch [1/3], Step [819/1875], Loss: 0.5749
# Epoch [1/3], Step [822/1875], Loss: 0.6401
# Epoch [1/3], Step [825/1875], Loss: 0.6996
# Epoch [1/3], Step [828/1875], Loss: 0.4166
# Epoch [1/3], Step [831/1875], Loss: 0.4125
# Epoch [1/3], Step [834/1875], Loss: 0.6779
# Epoch [1/3], Step [837/1875], Loss: 0.6810
# Epoch [1/3], Step [840/1875], Loss: 0.4973
# Epoch [1/3], Step [843/1875], Loss: 0.7204
# Epoch [1/3], Step [846/1875], Loss: 0.7094
# Epoch [1/3], Step [849/1875], Loss: 1.1387
# Epoch [1/3], Step [852/1875], Loss: 0.6455
# Epoch [1/3], Step [855/1875], Loss: 0.8289
# Epoch [1/3], Step [858/1875], Loss: 0.4461
# Epoch [1/3], Step [861/1875], Loss: 0.6950
# Epoch [1/3], Step [864/1875], Loss: 0.4325
# Epoch [1/3], Step [867/1875], Loss: 0.5834
# Epoch [1/3], Step [870/1875], Loss: 0.6971
# Epoch [1/3], Step [873/1875], Loss: 0.6466
# Epoch [1/3], Step [876/1875], Loss: 0.7580
# Epoch [1/3], Step [879/1875], Loss: 0.3134
# Epoch [1/3], Step [882/1875], Loss: 0.5090
# Epoch [1/3], Step [885/1875], Loss: 0.7120
# Epoch [1/3], Step [888/1875], Loss: 0.4596
# Epoch [1/3], Step [891/1875], Loss: 0.7127
# Epoch [1/3], Step [894/1875], Loss: 0.5667
# Epoch [1/3], Step [897/1875], Loss: 0.4736
# Epoch [1/3], Step [900/1875], Loss: 0.6084
# Epoch [1/3], Step [903/1875], Loss: 0.5916
# Epoch [1/3], Step [906/1875], Loss: 0.9772
# Epoch [1/3], Step [909/1875], Loss: 0.6379
# Epoch [1/3], Step [912/1875], Loss: 0.2657
# Epoch [1/3], Step [915/1875], Loss: 0.5175
# Epoch [1/3], Step [918/1875], Loss: 0.6072
# Epoch [1/3], Step [921/1875], Loss: 0.8182
# Epoch [1/3], Step [924/1875], Loss: 0.4590
# Epoch [1/3], Step [927/1875], Loss: 0.5802
# Epoch [1/3], Step [930/1875], Loss: 0.5720
# Epoch [1/3], Step [933/1875], Loss: 0.3606
# Epoch [1/3], Step [936/1875], Loss: 0.3451
# Epoch [1/3], Step [939/1875], Loss: 0.7381
# Epoch [1/3], Step [942/1875], Loss: 1.0475
# Epoch [1/3], Step [945/1875], Loss: 0.4849
# Epoch [1/3], Step [948/1875], Loss: 0.3964
# Epoch [1/3], Step [951/1875], Loss: 0.3031
# Epoch [1/3], Step [954/1875], Loss: 0.6640
# Epoch [1/3], Step [957/1875], Loss: 0.3470
# Epoch [1/3], Step [960/1875], Loss: 0.5087
# Epoch [1/3], Step [963/1875], Loss: 0.2515
# Epoch [1/3], Step [966/1875], Loss: 0.5373
# Epoch [1/3], Step [969/1875], Loss: 0.4937
# Epoch [1/3], Step [972/1875], Loss: 0.9737
# Epoch [1/3], Step [975/1875], Loss: 0.3464
# Epoch [1/3], Step [978/1875], Loss: 0.4151
# Epoch [1/3], Step [981/1875], Loss: 0.5781
# Epoch [1/3], Step [984/1875], Loss: 0.4139
# Epoch [1/3], Step [987/1875], Loss: 0.4510
# Epoch [1/3], Step [990/1875], Loss: 0.5083
# Epoch [1/3], Step [993/1875], Loss: 0.4028
# Epoch [1/3], Step [996/1875], Loss: 0.5188
# Epoch [1/3], Step [999/1875], Loss: 0.5158
# Epoch [1/3], Step [1002/1875], Loss: 0.3432
# Epoch [1/3], Step [1005/1875], Loss: 0.6264
# Epoch [1/3], Step [1008/1875], Loss: 0.4768
# Epoch [1/3], Step [1011/1875], Loss: 0.3572
# Epoch [1/3], Step [1014/1875], Loss: 0.4947
# Epoch [1/3], Step [1017/1875], Loss: 0.4521
# Epoch [1/3], Step [1020/1875], Loss: 0.3811
# Epoch [1/3], Step [1023/1875], Loss: 0.5388
# Epoch [1/3], Step [1026/1875], Loss: 0.5135
# Epoch [1/3], Step [1029/1875], Loss: 0.3401
# Epoch [1/3], Step [1032/1875], Loss: 0.6490
# Epoch [1/3], Step [1035/1875], Loss: 0.4323
# Epoch [1/3], Step [1038/1875], Loss: 0.2503
# Epoch [1/3], Step [1041/1875], Loss: 0.4659
# Epoch [1/3], Step [1044/1875], Loss: 0.4697
# Epoch [1/3], Step [1047/1875], Loss: 0.3666
# Epoch [1/3], Step [1050/1875], Loss: 0.5960
# Epoch [1/3], Step [1053/1875], Loss: 0.6728
# Epoch [1/3], Step [1056/1875], Loss: 0.4281
# Epoch [1/3], Step [1059/1875], Loss: 0.5071
# Epoch [1/3], Step [1062/1875], Loss: 0.6408
# Epoch [1/3], Step [1065/1875], Loss: 0.1970
# Epoch [1/3], Step [1068/1875], Loss: 0.5840
# Epoch [1/3], Step [1071/1875], Loss: 0.4713
# Epoch [1/3], Step [1074/1875], Loss: 0.5418
# Epoch [1/3], Step [1077/1875], Loss: 1.0069
# Epoch [1/3], Step [1080/1875], Loss: 0.6276
# Epoch [1/3], Step [1083/1875], Loss: 0.4515
# Epoch [1/3], Step [1086/1875], Loss: 0.4135
# Epoch [1/3], Step [1089/1875], Loss: 0.5392
# Epoch [1/3], Step [1092/1875], Loss: 0.6960
# Epoch [1/3], Step [1095/1875], Loss: 0.8045
# Epoch [1/3], Step [1098/1875], Loss: 0.5056
# Epoch [1/3], Step [1101/1875], Loss: 0.2782
# Epoch [1/3], Step [1104/1875], Loss: 0.5187
# Epoch [1/3], Step [1107/1875], Loss: 0.5280
# Epoch [1/3], Step [1110/1875], Loss: 0.6718
# Epoch [1/3], Step [1113/1875], Loss: 0.7503
# Epoch [1/3], Step [1116/1875], Loss: 0.4585
# Epoch [1/3], Step [1119/1875], Loss: 0.6576
# Epoch [1/3], Step [1122/1875], Loss: 0.6215
# Epoch [1/3], Step [1125/1875], Loss: 0.7282
# Epoch [1/3], Step [1128/1875], Loss: 0.5764
# Epoch [1/3], Step [1131/1875], Loss: 0.4530
# Epoch [1/3], Step [1134/1875], Loss: 0.3567
# Epoch [1/3], Step [1137/1875], Loss: 0.5698
# Epoch [1/3], Step [1140/1875], Loss: 0.2656
# Epoch [1/3], Step [1143/1875], Loss: 0.4046
# Epoch [1/3], Step [1146/1875], Loss: 0.7480
# Epoch [1/3], Step [1149/1875], Loss: 0.3940
# Epoch [1/3], Step [1152/1875], Loss: 0.4031
# Epoch [1/3], Step [1155/1875], Loss: 0.4139
# Epoch [1/3], Step [1158/1875], Loss: 0.6951
# Epoch [1/3], Step [1161/1875], Loss: 0.6486
# Epoch [1/3], Step [1164/1875], Loss: 0.2907
# Epoch [1/3], Step [1167/1875], Loss: 0.2937
# Epoch [1/3], Step [1170/1875], Loss: 0.5677
# Epoch [1/3], Step [1173/1875], Loss: 0.5122
# Epoch [1/3], Step [1176/1875], Loss: 0.6633
# Epoch [1/3], Step [1179/1875], Loss: 0.7026
# Epoch [1/3], Step [1182/1875], Loss: 0.4326
# Epoch [1/3], Step [1185/1875], Loss: 0.4332
# Epoch [1/3], Step [1188/1875], Loss: 0.4421
# Epoch [1/3], Step [1191/1875], Loss: 0.6320
# Epoch [1/3], Step [1194/1875], Loss: 0.2914
# Epoch [1/3], Step [1197/1875], Loss: 0.6189
# Epoch [1/3], Step [1200/1875], Loss: 0.2704
# Epoch [1/3], Step [1203/1875], Loss: 0.3424
# Epoch [1/3], Step [1206/1875], Loss: 0.2754
# Epoch [1/3], Step [1524/1875], Loss: 0.6347
# Epoch [1/3], Step [1527/1875], Loss: 0.7258
# Epoch [1/3], Step [1530/1875], Loss: 1.0872
# Epoch [1/3], Step [1533/1875], Loss: 0.4819
# Epoch [1/3], Step [1536/1875], Loss: 0.6698
# Epoch [1/3], Step [1539/1875], Loss: 0.4978
# Epoch [1/3], Step [1542/1875], Loss: 0.3021
# Epoch [1/3], Step [1545/1875], Loss: 0.3497
# Epoch [1/3], Step [1548/1875], Loss: 0.5054
# Epoch [1/3], Step [1551/1875], Loss: 0.4707
# Epoch [1/3], Step [1554/1875], Loss: 0.5591
# Epoch [1/3], Step [1557/1875], Loss: 0.7036
# Epoch [1/3], Step [1560/1875], Loss: 0.3582
# Epoch [1/3], Step [1563/1875], Loss: 0.4409
# Epoch [1/3], Step [1566/1875], Loss: 0.2772
# Epoch [1/3], Step [1569/1875], Loss: 0.4822
# Epoch [1/3], Step [1572/1875], Loss: 0.3102
# Epoch [1/3], Step [1575/1875], Loss: 0.3568
# Epoch [1/3], Step [1578/1875], Loss: 0.6053
# Epoch [1/3], Step [1581/1875], Loss: 0.5522
# Epoch [1/3], Step [1584/1875], Loss: 0.2604
# Epoch [1/3], Step [1587/1875], Loss: 0.2882
# Epoch [1/3], Step [1590/1875], Loss: 0.3686
# Epoch [1/3], Step [1593/1875], Loss: 0.5688
# Epoch [1/3], Step [1596/1875], Loss: 0.2815
# Epoch [1/3], Step [1599/1875], Loss: 0.4822
# Epoch [1/3], Step [1602/1875], Loss: 0.8024
# Epoch [1/3], Step [1605/1875], Loss: 0.6532
# Epoch [1/3], Step [1608/1875], Loss: 0.2602
# Epoch [1/3], Step [1611/1875], Loss: 0.3990
# Epoch [1/3], Step [1614/1875], Loss: 0.5178
# Epoch [1/3], Step [1617/1875], Loss: 0.6537
# Epoch [1/3], Step [1620/1875], Loss: 0.5838
# Epoch [1/3], Step [1623/1875], Loss: 0.3937
# Epoch [1/3], Step [1626/1875], Loss: 0.4436
# Epoch [1/3], Step [1629/1875], Loss: 0.5472
# Epoch [1/3], Step [1632/1875], Loss: 0.3059
# Epoch [1/3], Step [1635/1875], Loss: 0.8166
# Epoch [1/3], Step [1638/1875], Loss: 0.2958
# Epoch [1/3], Step [1641/1875], Loss: 0.4646
# Epoch [1/3], Step [1644/1875], Loss: 0.6500
# Epoch [1/3], Step [1647/1875], Loss: 0.3477
# Epoch [1/3], Step [1650/1875], Loss: 0.4885
# Epoch [1/3], Step [1653/1875], Loss: 0.5821
# Epoch [1/3], Step [1656/1875], Loss: 0.4353
# Epoch [1/3], Step [1659/1875], Loss: 0.3475
# Epoch [1/3], Step [1662/1875], Loss: 0.6924
# Epoch [1/3], Step [1665/1875], Loss: 0.6755
# Epoch [1/3], Step [1668/1875], Loss: 0.6053
# Epoch [1/3], Step [1671/1875], Loss: 0.4073
# Epoch [1/3], Step [1674/1875], Loss: 0.1993
# Epoch [1/3], Step [1677/1875], Loss: 0.4932
# Epoch [2/3], Step [126/1875], Loss: 0.7133
# Epoch [2/3], Step [129/1875], Loss: 0.3615
# Epoch [2/3], Step [132/1875], Loss: 0.2633
# Epoch [2/3], Step [135/1875], Loss: 0.5379
# Epoch [2/3], Step [138/1875], Loss: 0.5381
# Epoch [2/3], Step [141/1875], Loss: 0.3894
# Epoch [2/3], Step [144/1875], Loss: 0.3796
# Epoch [2/3], Step [147/1875], Loss: 0.3150
# Epoch [2/3], Step [150/1875], Loss: 0.4110
# Epoch [2/3], Step [153/1875], Loss: 0.4145
# Epoch [2/3], Step [156/1875], Loss: 0.2368
# Epoch [2/3], Step [159/1875], Loss: 0.5912
# Epoch [2/3], Step [162/1875], Loss: 0.3953
# Epoch [2/3], Step [165/1875], Loss: 0.2366
# Epoch [2/3], Step [168/1875], Loss: 0.6187
# Epoch [2/3], Step [171/1875], Loss: 0.3385
# Epoch [2/3], Step [174/1875], Loss: 0.3744
# Epoch [2/3], Step [177/1875], Loss: 0.4274
# Epoch [2/3], Step [180/1875], Loss: 0.6130
# Epoch [2/3], Step [183/1875], Loss: 0.7130
# Epoch [2/3], Step [186/1875], Loss: 0.3119
# Epoch [2/3], Step [189/1875], Loss: 0.2486
# Epoch [2/3], Step [192/1875], Loss: 0.6770
# Epoch [2/3], Step [195/1875], Loss: 0.5270
# Epoch [2/3], Step [198/1875], Loss: 0.4064
# Epoch [2/3], Step [201/1875], Loss: 0.6202
# Epoch [2/3], Step [204/1875], Loss: 0.5924
# Epoch [2/3], Step [207/1875], Loss: 0.5464
# Epoch [2/3], Step [210/1875], Loss: 0.5582
# Epoch [2/3], Step [213/1875], Loss: 0.4464
# Epoch [2/3], Step [216/1875], Loss: 0.7876
# Epoch [2/3], Step [219/1875], Loss: 0.7813
# Epoch [2/3], Step [222/1875], Loss: 0.3942
# Epoch [2/3], Step [225/1875], Loss: 0.6274
# Epoch [2/3], Step [228/1875], Loss: 0.8632
# Epoch [2/3], Step [231/1875], Loss: 0.3960
# Epoch [2/3], Step [234/1875], Loss: 0.4848
# Epoch [2/3], Step [237/1875], Loss: 0.2328
# Epoch [2/3], Step [240/1875], Loss: 0.3129
# Epoch [2/3], Step [243/1875], Loss: 0.6399
# Epoch [2/3], Step [246/1875], Loss: 0.3555
# Epoch [2/3], Step [249/1875], Loss: 0.7949
# Epoch [2/3], Step [252/1875], Loss: 0.3382
# Epoch [2/3], Step [255/1875], Loss: 0.4189
# Epoch [2/3], Step [258/1875], Loss: 0.1628
# Epoch [2/3], Step [261/1875], Loss: 0.3777
# Epoch [2/3], Step [264/1875], Loss: 0.2406
# Epoch [2/3], Step [267/1875], Loss: 0.4512
# Epoch [2/3], Step [270/1875], Loss: 0.6744
# Epoch [2/3], Step [273/1875], Loss: 0.4204
# Epoch [2/3], Step [276/1875], Loss: 0.4207
# Epoch [2/3], Step [279/1875], Loss: 0.2812
# Epoch [2/3], Step [282/1875], Loss: 0.4117
# Epoch [2/3], Step [285/1875], Loss: 0.6244
# Epoch [2/3], Step [288/1875], Loss: 0.3967
# Epoch [2/3], Step [291/1875], Loss: 0.7241
# Epoch [2/3], Step [294/1875], Loss: 0.4486
# Epoch [2/3], Step [297/1875], Loss: 0.3514
# Epoch [2/3], Step [300/1875], Loss: 0.4246
# Epoch [2/3], Step [303/1875], Loss: 0.6128
# Epoch [2/3], Step [306/1875], Loss: 0.3873
# Epoch [2/3], Step [309/1875], Loss: 0.8102
# Epoch [2/3], Step [312/1875], Loss: 0.6738
# Epoch [2/3], Step [315/1875], Loss: 0.6514
# Epoch [2/3], Step [318/1875], Loss: 0.2904
# Epoch [2/3], Step [321/1875], Loss: 0.6201
# Epoch [2/3], Step [324/1875], Loss: 0.2438
# Epoch [2/3], Step [327/1875], Loss: 0.6339
# Epoch [2/3], Step [330/1875], Loss: 0.4533
# Epoch [2/3], Step [333/1875], Loss: 0.5643
# Epoch [2/3], Step [336/1875], Loss: 0.1740
# Epoch [2/3], Step [339/1875], Loss: 0.7267
# Epoch [2/3], Step [342/1875], Loss: 0.6560
# Epoch [2/3], Step [345/1875], Loss: 0.8662
# Epoch [2/3], Step [348/1875], Loss: 0.5463
# Epoch [2/3], Step [351/1875], Loss: 0.6519
# Epoch [2/3], Step [354/1875], Loss: 0.4620
# Epoch [2/3], Step [357/1875], Loss: 0.5463
# Epoch [2/3], Step [360/1875], Loss: 0.5822
# Epoch [2/3], Step [363/1875], Loss: 0.4162
# Epoch [2/3], Step [366/1875], Loss: 0.4557
# Epoch [2/3], Step [369/1875], Loss: 0.6604
# Epoch [2/3], Step [372/1875], Loss: 0.2431
# Epoch [2/3], Step [375/1875], Loss: 0.2510
# Epoch [2/3], Step [378/1875], Loss: 0.4059
# Epoch [2/3], Step [381/1875], Loss: 0.3347
# Epoch [2/3], Step [384/1875], Loss: 0.4698
# Epoch [2/3], Step [387/1875], Loss: 0.6881
# Epoch [2/3], Step [390/1875], Loss: 0.4745
# Epoch [2/3], Step [393/1875], Loss: 0.5328
# Epoch [2/3], Step [396/1875], Loss: 0.6734
# Epoch [2/3], Step [399/1875], Loss: 0.3089
# Epoch [2/3], Step [402/1875], Loss: 0.5056
# Epoch [2/3], Step [405/1875], Loss: 0.9229
# Epoch [2/3], Step [408/1875], Loss: 0.3517
# Epoch [2/3], Step [411/1875], Loss: 0.2489
# Epoch [2/3], Step [414/1875], Loss: 0.3167
# Epoch [2/3], Step [417/1875], Loss: 0.2583
# Epoch [2/3], Step [420/1875], Loss: 0.4327
# Epoch [2/3], Step [423/1875], Loss: 0.5337
# Epoch [2/3], Step [426/1875], Loss: 0.4770
# Epoch [2/3], Step [429/1875], Loss: 1.0172
# Epoch [2/3], Step [432/1875], Loss: 0.4178
# Epoch [2/3], Step [435/1875], Loss: 0.2606
# Epoch [2/3], Step [438/1875], Loss: 0.4423
# Epoch [2/3], Step [441/1875], Loss: 0.4735
# Epoch [2/3], Step [444/1875], Loss: 0.6283
# Epoch [2/3], Step [447/1875], Loss: 0.2646
# Epoch [2/3], Step [450/1875], Loss: 0.2729
# Epoch [2/3], Step [453/1875], Loss: 0.6087
# Epoch [2/3], Step [456/1875], Loss: 0.6331
# Epoch [2/3], Step [459/1875], Loss: 0.3056
# Epoch [2/3], Step [462/1875], Loss: 0.3871
# Epoch [2/3], Step [465/1875], Loss: 0.3158
# Epoch [2/3], Step [468/1875], Loss: 0.9385
# Epoch [2/3], Step [471/1875], Loss: 0.4810
# Epoch [2/3], Step [474/1875], Loss: 0.3124
# Epoch [2/3], Step [477/1875], Loss: 0.7950
# Epoch [2/3], Step [480/1875], Loss: 0.3937
# Epoch [2/3], Step [483/1875], Loss: 0.9449
# Epoch [2/3], Step [486/1875], Loss: 0.3964
# Epoch [2/3], Step [489/1875], Loss: 0.5063
# Epoch [2/3], Step [492/1875], Loss: 0.3920
# Epoch [2/3], Step [495/1875], Loss: 0.4412
# Epoch [2/3], Step [498/1875], Loss: 0.4741
# Epoch [2/3], Step [501/1875], Loss: 0.2565
# Epoch [2/3], Step [504/1875], Loss: 0.3919
# Epoch [2/3], Step [507/1875], Loss: 0.4933
# Epoch [2/3], Step [510/1875], Loss: 0.2145
# Epoch [2/3], Step [513/1875], Loss: 0.2939
# Epoch [2/3], Step [516/1875], Loss: 0.4684
# Epoch [2/3], Step [519/1875], Loss: 0.3502
# Epoch [2/3], Step [522/1875], Loss: 0.2753
# Epoch [2/3], Step [525/1875], Loss: 0.6010
# Epoch [2/3], Step [528/1875], Loss: 0.5688
# Epoch [2/3], Step [531/1875], Loss: 0.7201
# Epoch [2/3], Step [534/1875], Loss: 0.5049
# Epoch [2/3], Step [537/1875], Loss: 0.7254
# Epoch [2/3], Step [540/1875], Loss: 0.3282
# Epoch [2/3], Step [543/1875], Loss: 0.6670
# Epoch [2/3], Step [546/1875], Loss: 0.7821
# Epoch [2/3], Step [549/1875], Loss: 0.4952
# Epoch [2/3], Step [552/1875], Loss: 0.5982
# Epoch [2/3], Step [555/1875], Loss: 0.4312
# Epoch [2/3], Step [558/1875], Loss: 0.3543
# Epoch [2/3], Step [561/1875], Loss: 0.3469
# Epoch [2/3], Step [564/1875], Loss: 0.2934
# Epoch [2/3], Step [567/1875], Loss: 0.4694
# Epoch [2/3], Step [570/1875], Loss: 0.2821
# Epoch [2/3], Step [573/1875], Loss: 0.5438
# Epoch [2/3], Step [576/1875], Loss: 0.6803
# Epoch [2/3], Step [579/1875], Loss: 0.4144
# Epoch [2/3], Step [582/1875], Loss: 1.0382
# Epoch [2/3], Step [585/1875], Loss: 0.3018
# Epoch [2/3], Step [588/1875], Loss: 0.2576
# Epoch [2/3], Step [591/1875], Loss: 0.3018
# Epoch [2/3], Step [594/1875], Loss: 0.4402
# Epoch [2/3], Step [597/1875], Loss: 0.2900
# Epoch [2/3], Step [600/1875], Loss: 0.3198
# Epoch [2/3], Step [603/1875], Loss: 0.6582
# Epoch [2/3], Step [606/1875], Loss: 0.7466
# Epoch [2/3], Step [609/1875], Loss: 0.8900
# Epoch [2/3], Step [612/1875], Loss: 0.3824
# Epoch [2/3], Step [777/1875], Loss: 0.6899
# Epoch [2/3], Step [780/1875], Loss: 0.5388
# Epoch [2/3], Step [783/1875], Loss: 0.4616
# Epoch [2/3], Step [786/1875], Loss: 0.4496
# Epoch [2/3], Step [789/1875], Loss: 0.3388
# Epoch [2/3], Step [792/1875], Loss: 0.7741
# Epoch [2/3], Step [795/1875], Loss: 0.5936
# Epoch [2/3], Step [798/1875], Loss: 0.3754
# Epoch [2/3], Step [801/1875], Loss: 0.4310
# Epoch [2/3], Step [804/1875], Loss: 0.5720
# Epoch [2/3], Step [807/1875], Loss: 0.3670
# Epoch [2/3], Step [810/1875], Loss: 0.4019
# Epoch [2/3], Step [813/1875], Loss: 0.5563
# Epoch [2/3], Step [816/1875], Loss: 0.2711
# Epoch [2/3], Step [819/1875], Loss: 0.3155
# Epoch [2/3], Step [822/1875], Loss: 0.5040
# Epoch [2/3], Step [825/1875], Loss: 0.6229
# Epoch [2/3], Step [828/1875], Loss: 0.4785
# Epoch [2/3], Step [831/1875], Loss: 0.9042
# Epoch [2/3], Step [834/1875], Loss: 0.2893
# Epoch [2/3], Step [837/1875], Loss: 0.3806
# Epoch [2/3], Step [840/1875], Loss: 0.4613
# Epoch [2/3], Step [843/1875], Loss: 0.3559
# Epoch [2/3], Step [846/1875], Loss: 0.3840
# Epoch [2/3], Step [849/1875], Loss: 0.2711
# Epoch [2/3], Step [852/1875], Loss: 0.2389
# Epoch [2/3], Step [855/1875], Loss: 0.3375
# Epoch [2/3], Step [858/1875], Loss: 0.2407
# Epoch [2/3], Step [861/1875], Loss: 0.5129
# Epoch [2/3], Step [864/1875], Loss: 0.6032
# Epoch [2/3], Step [867/1875], Loss: 0.3622
# Epoch [2/3], Step [870/1875], Loss: 0.6964
# Epoch [2/3], Step [873/1875], Loss: 0.3755
# Epoch [2/3], Step [876/1875], Loss: 0.5650
# Epoch [2/3], Step [879/1875], Loss: 0.6210
# Epoch [2/3], Step [882/1875], Loss: 0.4123
# Epoch [2/3], Step [885/1875], Loss: 0.6540
# Epoch [2/3], Step [888/1875], Loss: 0.3491
# Epoch [2/3], Step [891/1875], Loss: 0.4185
# Epoch [2/3], Step [894/1875], Loss: 0.5740
# Epoch [2/3], Step [897/1875], Loss: 0.4565
# Epoch [2/3], Step [900/1875], Loss: 0.4286
# Epoch [2/3], Step [903/1875], Loss: 0.3163
# Epoch [2/3], Step [906/1875], Loss: 0.2618
# Epoch [2/3], Step [909/1875], Loss: 0.4123
# Epoch [2/3], Step [912/1875], Loss: 0.5224
# Epoch [2/3], Step [915/1875], Loss: 0.6876
# Epoch [2/3], Step [918/1875], Loss: 0.6058
# Epoch [2/3], Step [921/1875], Loss: 0.8976
# Epoch [2/3], Step [924/1875], Loss: 0.4493
# Epoch [2/3], Step [927/1875], Loss: 0.6499
# Epoch [2/3], Step [930/1875], Loss: 0.2304
# Epoch [2/3], Step [933/1875], Loss: 0.4301
# Epoch [2/3], Step [936/1875], Loss: 0.4569
# Epoch [3/3], Step [909/1875], Loss: 0.1713
# Epoch [3/3], Step [912/1875], Loss: 0.4265
# Epoch [3/3], Step [915/1875], Loss: 0.3895
# Epoch [3/3], Step [918/1875], Loss: 0.6433
# Epoch [3/3], Step [921/1875], Loss: 0.6254
# Epoch [3/3], Step [924/1875], Loss: 0.4673
# Epoch [3/3], Step [927/1875], Loss: 0.2154
# Epoch [3/3], Step [930/1875], Loss: 0.8859
# Epoch [3/3], Step [933/1875], Loss: 0.6944
# Epoch [3/3], Step [936/1875], Loss: 0.6958
# Epoch [3/3], Step [939/1875], Loss: 0.4634
# Epoch [3/3], Step [942/1875], Loss: 0.3182
# Epoch [3/3], Step [945/1875], Loss: 0.3960
# Epoch [3/3], Step [948/1875], Loss: 0.4645
# Epoch [3/3], Step [951/1875], Loss: 0.2147
# Epoch [3/3], Step [954/1875], Loss: 0.3268
# Epoch [3/3], Step [957/1875], Loss: 0.1963
# Epoch [3/3], Step [960/1875], Loss: 0.3741
# Epoch [3/3], Step [963/1875], Loss: 0.2878
# Epoch [3/3], Step [966/1875], Loss: 0.9314
# Epoch [3/3], Step [969/1875], Loss: 0.6289
# Epoch [3/3], Step [972/1875], Loss: 0.8694
# Epoch [3/3], Step [975/1875], Loss: 0.6908
# Epoch [3/3], Step [978/1875], Loss: 0.8261
# Epoch [3/3], Step [981/1875], Loss: 0.3608
# Epoch [3/3], Step [984/1875], Loss: 0.3725
# Epoch [3/3], Step [987/1875], Loss: 0.8645
# Epoch [3/3], Step [990/1875], Loss: 0.4066
# Epoch [3/3], Step [993/1875], Loss: 0.6995
# Epoch [3/3], Step [996/1875], Loss: 0.4550
# Epoch [3/3], Step [999/1875], Loss: 0.5266
# Epoch [3/3], Step [1002/1875], Loss: 0.5839
# Epoch [3/3], Step [1005/1875], Loss: 0.5361
# Epoch [3/3], Step [1008/1875], Loss: 0.3506
# Epoch [3/3], Step [1011/1875], Loss: 0.4751
# Epoch [3/3], Step [1014/1875], Loss: 0.3501
# Epoch [3/3], Step [1017/1875], Loss: 0.4035
# Epoch [3/3], Step [1020/1875], Loss: 0.2880
# Epoch [3/3], Step [1023/1875], Loss: 0.3210
# Epoch [3/3], Step [1026/1875], Loss: 0.3764
# Epoch [3/3], Step [1029/1875], Loss: 0.2697
# Epoch [3/3], Step [1032/1875], Loss: 0.4457
# Epoch [3/3], Step [1035/1875], Loss: 0.6049
# Epoch [3/3], Step [1038/1875], Loss: 0.3384
# Epoch [3/3], Step [1041/1875], Loss: 0.4506
# Epoch [3/3], Step [1044/1875], Loss: 0.3189
# Epoch [3/3], Step [1047/1875], Loss: 0.3667
# Epoch [3/3], Step [1050/1875], Loss: 0.9383
# Epoch [3/3], Step [1053/1875], Loss: 0.4465
# Epoch [3/3], Step [1056/1875], Loss: 0.5628
# Epoch [3/3], Step [1059/1875], Loss: 0.5099
# Epoch [3/3], Step [1062/1875], Loss: 0.4486
# Epoch [3/3], Step [1065/1875], Loss: 0.5412
# Epoch [3/3], Step [1068/1875], Loss: 0.5732
# Epoch [3/3], Step [1701/1875], Loss: 0.4281
# Epoch [3/3], Step [1704/1875], Loss: 0.5141
# Epoch [3/3], Step [1707/1875], Loss: 0.5301
# Epoch [3/3], Step [1710/1875], Loss: 0.6070
# Epoch [3/3], Step [1713/1875], Loss: 0.2966
# Epoch [3/3], Step [1716/1875], Loss: 0.6428
# Epoch [3/3], Step [1719/1875], Loss: 0.4955
# Epoch [3/3], Step [1722/1875], Loss: 0.9567
# Epoch [3/3], Step [1725/1875], Loss: 0.6012
# Epoch [3/3], Step [1728/1875], Loss: 0.4210
# Epoch [3/3], Step [1731/1875], Loss: 0.3326
# Epoch [3/3], Step [1734/1875], Loss: 0.3476
# Epoch [3/3], Step [1737/1875], Loss: 0.2721
# Epoch [3/3], Step [1740/1875], Loss: 0.3161
# Epoch [3/3], Step [1743/1875], Loss: 0.6840
# Epoch [3/3], Step [1746/1875], Loss: 0.6618
# Epoch [3/3], Step [1749/1875], Loss: 0.5692
# Epoch [3/3], Step [1752/1875], Loss: 0.3000
# Epoch [3/3], Step [1755/1875], Loss: 0.7505
# Epoch [3/3], Step [1758/1875], Loss: 0.4807
# Epoch [3/3], Step [1761/1875], Loss: 0.3949
# Epoch [3/3], Step [1764/1875], Loss: 0.3942
# Epoch [3/3], Step [1767/1875], Loss: 0.4267
# Epoch [3/3], Step [1770/1875], Loss: 0.3187
# Epoch [3/3], Step [1773/1875], Loss: 0.3879
# Epoch [3/3], Step [1776/1875], Loss: 0.3715
# Epoch [3/3], Step [1779/1875], Loss: 0.4137
# Epoch [3/3], Step [1782/1875], Loss: 0.6080
# Epoch [3/3], Step [1785/1875], Loss: 0.0990
# Epoch [3/3], Step [1788/1875], Loss: 0.3103
# Epoch [3/3], Step [1791/1875], Loss: 0.5305
# Epoch [3/3], Step [1794/1875], Loss: 0.4518
# Epoch [3/3], Step [1797/1875], Loss: 0.2472
# Epoch [3/3], Step [1800/1875], Loss: 0.2321
# Epoch [3/3], Step [1803/1875], Loss: 0.4854
# Epoch [3/3], Step [1806/1875], Loss: 0.1971
# Epoch [3/3], Step [1809/1875], Loss: 0.8559
# Epoch [3/3], Step [1812/1875], Loss: 0.2033
# Epoch [3/3], Step [1815/1875], Loss: 0.3652
# Epoch [3/3], Step [1818/1875], Loss: 0.2993
# Epoch [3/3], Step [1821/1875], Loss: 0.6362
# Epoch [3/3], Step [1824/1875], Loss: 0.3572
# Epoch [3/3], Step [1827/1875], Loss: 0.7038
# Epoch [3/3], Step [1830/1875], Loss: 0.7140
# Epoch [3/3], Step [1833/1875], Loss: 0.4438
# Epoch [3/3], Step [1836/1875], Loss: 0.4147
# Epoch [3/3], Step [1839/1875], Loss: 0.2308
# Epoch [3/3], Step [1842/1875], Loss: 0.3227
# Epoch [3/3], Step [1845/1875], Loss: 0.5578
# Epoch [3/3], Step [1848/1875], Loss: 0.5846
# Epoch [3/3], Step [1851/1875], Loss: 0.6759
# Epoch [3/3], Step [1854/1875], Loss: 0.5095
# Epoch [3/3], Step [1857/1875], Loss: 0.2969
# Epoch [3/3], Step [1860/1875], Loss: 0.2920
# Epoch [3/3], Step [1863/1875], Loss: 0.5995
# Epoch [3/3], Step [1866/1875], Loss: 0.4850
# Epoch [3/3], Step [1869/1875], Loss: 0.4621
# Epoch [3/3], Step [1872/1875], Loss: 0.4471
# Epoch [3/3], Step [1875/1875], Loss: 0.5000

# %%
# Ex 7 Finish the training loop instructions
# Import tqdm for progress bar
from tqdm.auto import tqdm

# Set the seed and start the timer
torch.manual_seed(42)
train_time_start_on_cpu = timer()

# Set the number of epochs (we'll keep this small for faster training times)
epochs = 3

# Create training and testing loop
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n-------")
    ### Training
    train_loss = 0
    # Add a loop to loop through training batches
    for batch, (X, y) in enumerate(train_dataloader):
        model_0.train()
        # 1. Forward pass
        y_pred = model_0(X)

        # 2. Calculate loss (per batch)
        loss = loss_fn(y_pred, y)
        train_loss += loss.item() * X.size(0)

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Print out how many samples have been seen
        if batch % 400 == 0:
            print(f"Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples")
    loss_values_arr.append(train_loss)

    ### Testing
    # Setup variables for accumulatively adding up loss and accuracy
    test_loss, test_acc = 0, 0
    model_0.eval()
    with torch.inference_mode():
        for X, y in test_dataloader:
            # 1. Forward pass
            test_pred = model_0(X)

            # 2. Calculate loss (accumatively)
            test_loss += loss_fn(test_pred, y) # accumulatively add up the loss per epoch

            # 3. Calculate accuracy (preds need to be same as y_true)
            test_acc += accuracy_fn(y_true=y, y_pred=test_pred.argmax(dim=1))

        # Calculations on test metrics need to happen inside torch.inference_mode()
        # Divide total test loss by length of test dataloader (per batch)
        test_loss /= len(test_dataloader)

        # Divide total accuracy by length of test dataloader (per batch)
        test_acc /= len(test_dataloader)

    ## Print out what's happening
    print(f"\nTrain loss: {train_loss:.5f} | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%\n")



# Calculate training time
train_time_end_on_cpu = timer()
total_train_time_model_0 = print_train_time(start=train_time_start_on_cpu,
                                           end=train_time_end_on_cpu)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 25587.54717 | Test loss: 0.45778, Test acc: 83.98%
#
# Epoch: 1
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 25400.85024 | Test loss: 0.45909, Test acc: 84.27%
#
# Epoch: 2
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 25178.86542 | Test loss: 0.46247, Test acc: 84.04%
#
# Train time on None: 31.219 seconds

# %%
plt.plot(np.arange(len(loss_values_arr)), loss_values_arr)
plt.title("Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
torch.manual_seed(42)
def eval_model(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               accuracy_fn):
    """
    Returns a dictionary containing the results of model predicting on data_loader.

    Args:
        model (torch.nn.Module): A PyTorch model capable of making predictions on data_loader.
        data_loader (torch.utils.data.DataLoader): The target dataset to predict on.
        loss_fn (torch.nn.Module): The loss function of model.
        accuracy_fn: An accuracy function to compare the models predictions to the truth labels.

    Returns:
        (dict): Results of model making predictions on data_loader.
    """
    loss, acc = 0, 0
    model.eval()
    with torch.inference_mode():
        for X, y in data_loader:
            # Make predictions with the model
            y_pred = model(X)

            # Accumulate the loss and accuracy values per batch
            loss += loss_fn(y_pred, y)
            acc += accuracy_fn(y_true=y,
                                y_pred=y_pred.argmax(dim=1)) # For accuracy, need the prediction labels (logits -> pred_prob -> pred_labels)

        # Scale loss and acc to find the average loss/acc per batch
        loss /= len(data_loader)
        acc /= len(data_loader)

    return {"model_name": model.__class__.__name__, # only works when model was created with a class
            "model_loss": loss.item(),
            "model_acc": acc}

# Calculate model 0 results on test dataset
model_0_results = eval_model(model=model_0, data_loader=test_dataloader,
    loss_fn=loss_fn, accuracy_fn=accuracy_fn
)
model_0_results
# Out:
# {'model_name': 'FashionMNISTModelV0',
#  'model_loss': 0.4624677300453186,
#  'model_acc': 84.03554313099042}

# %%
#ex9 Recreate the model by adding non linearities. The model needs again to flatten the image to a 1 D array and then add in between the linear layers ReLU. At the end you will have Flatten + Linear + ReLU + Linear + ReLU. We also try to speed up some things.
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
from torch import nn
class FashionMNISTModelV1(nn.Module):
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.layer_stack = nn.Sequential(
            # Exercise 9 here
            torch.nn.Flatten(),
            torch.nn.Linear(input_shape, hidden_units),
            nn.ReLU(inplace=True),
            torch.nn.Linear(hidden_units, output_shape),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.layer_stack(x)

# %%
torch.manual_seed(42)

model_1 = FashionMNISTModelV1(input_shape=784,
    hidden_units=10,
    output_shape=len(class_names)
).to(device)

next(model_1.parameters()).device
# Out:
# device(type='cpu')

# %%
#ex10 Create the same loss + optimizer as for V0. Make sure to use after the for loop if you are using a GPU. Send data to GPU.
loss_fn = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model_1.parameters(), lr=0.1)

# %%
# Task 11 Train And Test it as before
from tqdm.auto import tqdm

torch.manual_seed(42)
train_time_start_on_cpu = timer()

epochs = 3

for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n-------")

    train_loss = 0
    for batch, (X, y) in enumerate(train_dataloader):
        X, y = X.to(device), y.to(device)
        model_1.train()
        y_pred = model_1(X)

        loss = loss_fn(y_pred, y)

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()

        if batch % 400 == 0:
            print(f"Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples")

    test_loss, test_acc = 0, 0
    model_1.eval()
    with torch.inference_mode():
        for X, y in test_dataloader:
            test_pred = model_1(X)

            test_loss += loss_fn(test_pred, y)

            test_acc += accuracy_fn(y_true=y, y_pred=test_pred.argmax(dim=1))

        test_loss /= len(test_dataloader)

        test_acc /= len(test_dataloader)

    print(f"\nTrain loss: {train_loss:.5f} | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%\n")

train_time_end_on_cpu = timer()
total_train_time_model_1 = print_train_time(start=train_time_start_on_cpu,
                                           end=train_time_end_on_cpu)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 0
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.95636, Test acc: 65.00%
#
# Epoch: 1
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.72227, Test acc: 73.91%
#
# Epoch: 2
# -------
# Looked at 0/60000 samples
# Looked at 12800/60000 samples
# Looked at 25600/60000 samples
# Looked at 38400/60000 samples
# Looked at 51200/60000 samples
#
# Train loss: 0.00000 | Test loss: 0.68500, Test acc: 75.02%
#
# Train time on None: 34.294 seconds

# %%
# Setup device agnostic code
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
torch.manual_seed(42)

# Create sample batch of random numbers with same size as image batch
images = torch.randn(size=(32, 3, 64, 64)) # [batch_size, color_channels, height, width]
test_image = images[0] # get a single image for testing

# %%
torch.manual_seed(42)

# Create a convolutional layer with same dimensions as TinyVGG
# (try changing any of the parameters and see what happens)
conv_layer = nn.Conv2d(in_channels=3,
                       out_channels=10,
                       kernel_size=3,
                       stride=1,
                       padding=0) # also try using "valid" or "same" here

# Pass the data through the convolutional layer
conv_layer(test_image) # Note: If running PyTorch <1.11.0, this will error because of shape issues (nn.Conv.2d() expects a 4d tensor as input)
# Out:
# tensor([[[ 1.5396,  0.0516,  0.6454,  ..., -0.3673,  0.8711,  0.4256],
#          [ 0.3662,  1.0114, -0.5997,  ...,  0.8983,  0.2809, -0.2741],
#          [ 1.2664, -1.4054,  0.3727,  ..., -0.3409,  1.2191, -0.0463],
#          ...,
#          [-0.1541,  0.5132, -0.3624,  ..., -0.2360, -0.4609, -0.0035],
#          [ 0.2981, -0.2432,  1.5012,  ..., -0.6289, -0.7283, -0.5767],
#          [-0.0386, -0.0781, -0.0388,  ...,  0.2842,  0.4228, -0.1802]],
#
#         [[-0.2840, -0.0319, -0.4455,  ..., -0.7956,  1.5599, -1.2449],
#          [ 0.2753, -0.1262, -0.6541,  ..., -0.2211,  0.1999, -0.8856],
#          [-0.5404, -1.5489,  0.0249,  ..., -0.5932, -1.0913, -0.3849],
#          ...,
#          [ 0.3870, -0.4064, -0.8236,  ...,  0.1734, -0.4330, -0.4951],
#          [-0.1984, -0.6386,  1.0263,  ..., -0.9401, -0.0585, -0.7833],
#          [-0.6306, -0.2052, -0.3694,  ..., -1.3248,  0.2456, -0.7134]],
#
#         [[ 0.4414,  0.5100,  0.4846,  ..., -0.8484,  0.2638,  1.1258],
#          [ 0.8117,  0.3191, -0.0157,  ...,  1.2686,  0.2319,  0.5003],
#          [ 0.3212,  0.0485, -0.2581,  ...,  0.2258,  0.2587, -0.8804],
#          ...,
#          [-0.1144, -0.1869,  0.0160,  ..., -0.8346,  0.0974,  0.8421],
#          [ 0.2941,  0.4417,  0.5866,  ..., -0.1224,  0.4814, -0.4799],
#          [ 0.6059, -0.0415, -0.2028,  ...,  0.1170,  0.2521, -0.4372]],
#
#         ...,
#
#         [[-0.2560, -0.0477,  0.6380,  ...,  0.6436,  0.7553, -0.7055],
#          [ 1.5595, -0.2209, -0.9486,  ..., -0.4876,  0.7754,  0.0750],
#          [-0.0797,  0.2471,  1.1300,  ...,  0.1505,  0.2354,  0.9576],
#          ...,
#          [ 1.1065,  0.6839,  1.2183,  ...,  0.3015, -0.1910, -0.1902],
#          [-0.3486, -0.7173, -0.3582,  ...,  0.4917,  0.7219,  0.1513],
#          [ 0.0119,  0.1017,  0.7839,  ..., -0.3752, -0.8127, -0.1257]],
#
#         [[ 0.3841,  1.1322,  0.1620,  ...,  0.7010,  0.0109,  0.6058],
#          [ 0.1664,  0.1873,  1.5924,  ...,  0.3733,  0.9096, -0.5399],
#          [ 0.4094, -0.0861, -0.7935,  ..., -0.1285, -0.9932, -0.3013],
#          ...,
#          [ 0.2688, -0.5630, -1.1902,  ...,  0.4493,  0.5404, -0.0103],
#          [ 0.0535,  0.4411,  0.5313,  ...,  0.0148, -1.0056,  0.3759],
#          [ 0.3031, -0.1590, -0.1316,  ..., -0.5384, -0.4271, -0.4876]],
#
#         [[-1.1865, -0.7280, -1.2331,  ..., -0.9013, -0.0542, -1.5949],
#          [-0.6345, -0.5920,  0.5326,  ..., -1.0395, -0.7963, -0.0647],
#          [-0.1132,  0.5166,  0.2569,  ...,  0.5595, -1.6881,  0.9485],
#          ...,
#          [-0.0254, -0.2669,  0.1927,  ..., -0.2917,  0.1088, -0.4807],
#          [-0.2609, -0.2328,  0.1404,  ..., -0.1325, -0.8436, -0.7524],
#          [-1.1399, -0.1751, -0.8705,  ...,  0.1589,  0.3377,  0.3493]]],
#        grad_fn=<SqueezeBackward1>)

# %%
# Create a convolutional neural network
class FashionMNISTModelV2(nn.Module):
    """
    Model architecture copying TinyVGG from:
    https://poloclub.github.io/cnn-explainer/
    """
    def __init__(self, input_shape: int, hidden_units: int, output_shape: int):
        super().__init__()
        self.block_1 = nn.Sequential(
            nn.Conv2d(in_channels=input_shape,
                      out_channels=hidden_units,
                      kernel_size=3, # how big is the square that's going over the image?
                      stride=1, # default
                      padding=1),# options = "valid" (no padding) or "same" (output has same shape as input) or int for specific number
            nn.ReLU(),
            nn.Conv2d(in_channels=hidden_units,
                      out_channels=hidden_units,
                      kernel_size=3,
                      stride=1,
                      padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2,
                         stride=2) # default stride value is same as kernel_size
        )
        self.block_2 = nn.Sequential(
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(hidden_units, hidden_units, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            # Where did this in_features shape come from?
            # It's because each layer of our network compresses and changes the shape of our inputs data.
            nn.Linear(in_features=hidden_units*7*7,
                      out_features=output_shape)
        )

    def forward(self, x: torch.Tensor):
        x = self.block_1(x)
        # print(x.shape)
        x = self.block_2(x)
        # print(x.shape)
        x = self.classifier(x)
        # print(x.shape)
        return x

torch.manual_seed(42)
model_2 = FashionMNISTModelV2(input_shape=1,
    hidden_units=10,
    output_shape=len(class_names)).to(device)
model_2
# Out:
# FashionMNISTModelV2(
#   (block_1): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (block_2): Sequential(
#     (0): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=490, out_features=10, bias=True)
#   )
# )

# %%
import torch
import torch.nn as nn

# Create a random 2D tensor of shape (1, 1, 4, 4)
input_tensor = torch.rand(1, 1, 4, 4)

# Define a max pooling layer with a kernel size of (2, 2)
maxpool_layer = nn.MaxPool2d(kernel_size=(2, 2))

# Apply the max pooling layer to the input tensor
output_tensor = maxpool_layer(input_tensor)

# Print the input and output tensor shapes
print("Input shape:", input_tensor.shape)
print("Output shape:", output_tensor.shape)
# Out:
# Input shape: torch.Size([1, 1, 4, 4])
# Output shape: torch.Size([1, 1, 2, 2])

# %%
# EX 12 Train and evaluate this model
# When training convert output from logits like
    # # Do the forward pass
    # y_logit = model_2(X)
    # # Turn predictions from logits -> prediction probabilities -> predictions labels
    # y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1)
# Also compare the results(accuracy) and the training time

import torch.optim as optim

loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model_1.parameters(), lr=0.1)


def train(model, train_loader, optimizer, loss_fn, device):
    model.train()
    train_loss = 0
    train_acc = 0

    for X, y in train_loader:
        X = X.to(device)
        y = y.to(device)

        optimizer.zero_grad()
        y_logit = model(X)

        loss = loss_fn(y_logit, y)
        loss.backward()
        optimizer.step()

        y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1)
        train_acc += (y_pred == y).sum().item()
        train_loss += loss.item()

    train_loss /= len(train_loader.dataset)
    train_acc /= len(train_loader.dataset)
    return train_loss, train_acc


def evaluate(model, test_loader, loss_fn, device):
    model.eval()
    test_loss = 0
    test_acc = 0

    with torch.no_grad():
        for X, y in test_loader:
            X = X.to(device)
            y = y.to(device)

            y_logit = model(X)
            loss = loss_fn(y_logit, y)

            y_pred = torch.softmax(y_logit, dim=1).argmax(dim=1)
            test_acc += (y_pred == y).sum().item()
            test_loss += loss.item()

    test_loss /= len(test_loader.dataset)
    test_acc /= len(test_loader.dataset)
    return test_loss, test_acc

# %%
# Also compare the results(accuracy) and the training time
import time

num_epochs = 5

for epoch in range(num_epochs):
    start_time = time.time()

    train_loss, train_acc = train(model_2, train_dataloader, optimizer, loss_fn, device)
    test_loss, test_acc = evaluate(model_2, test_dataloader, loss_fn, device)

    end_time = time.time()

    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}, Time: {end_time-start_time:.2f}s")
# Out:
# Epoch 1/5, Train Loss: 0.0719, Train Acc: 0.1000, Test Loss: 0.0721, Test Acc: 0.1000, Time: 53.95s
# Epoch 2/5, Train Loss: 0.0719, Train Acc: 0.1000, Test Loss: 0.0721, Test Acc: 0.1000, Time: 52.46s
# Epoch 3/5, Train Loss: 0.0719, Train Acc: 0.1000, Test Loss: 0.0721, Test Acc: 0.1000, Time: 53.63s
# Epoch 4/5, Train Loss: 0.0719, Train Acc: 0.1000, Test Loss: 0.0721, Test Acc: 0.1000, Time: 52.91s
# Epoch 5/5, Train Loss: 0.0719, Train Acc: 0.1000, Test Loss: 0.0721, Test Acc: 0.1000, Time: 52.65s
